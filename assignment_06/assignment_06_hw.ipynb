# %% [markdown]
# <a href="https://colab.research.google.com/github/sruthib22/data690_Sruthi/blob/main/assignment_06/assignment_06_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 06
# ### Note:
# - For visualization, you should use Plotly Express
# - Use use this notebook as your template and follow the instructions
#
# The first half of this assignment is a repeat of assignment 05.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# The links to the zip file is:
#
# - https://data.ed.gov/dataset/college-scorecard-all-data-files-through-6-2020/resources (The page containing link to the zip file)
#
# - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip (The link to download the zip file)
#
# You can upload the zip file there or run `!wget` command to retrieve it directly, then run `!unzip` command to extract files.
#
# You can also unzip and upload individual files to Colab.
#
# Your folder structure should look like this in your Colab enviroment:
# ```
# - assignment_07.ipynb
# - raw_data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'
#         - ...
# ```

# %%
# !wget https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip
# Out:
# --2021-10-13 17:35:14--  https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip
# Resolving ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)... 15.205.92.235, 15.200.243.39, 2600:1f12:18a:7d01:29c7:6ff5:8ad8:c8f0, ...
# Connecting to ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)|15.205.92.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385541173 (368M) [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data_01192021.zip’
#
# CollegeScorecard_Ra   9%[>                   ]  35.98M  22.0MB/s    in 1.6s
#
# 2021-10-13 17:35:16 (22.0 MB/s) - Connection closed at byte 37727831. Retrying.
#
# --2021-10-13 17:35:17--  (try: 2)  https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip
# Connecting to ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)|15.205.92.235|:443... connected.
# ...

# %%
# !unzip CollegeScorecard_Raw_Data_01192021.zip
# Out:
# Archive:  CollegeScorecard_Raw_Data_01192021.zip
#    creating: Raw Data Files/
#   inflating: Raw Data Files/MERGED2011_12_PP.csv
#   inflating: Raw Data Files/MERGED1999_00_PP.csv
#   inflating: Raw Data Files/MERGED2006_07_PP.csv
#   inflating: Raw Data Files/MERGED2014_15_PP.csv
#   inflating: Raw Data Files/Most-Recent-Cohorts-All-Data-Elements.csv
#   inflating: __MACOSX/Raw Data Files/._Most-Recent-Cohorts-All-Data-Elements.csv
#   inflating: Raw Data Files/MERGED2003_04_PP.csv
#   inflating: Raw Data Files/MERGED1996_97_PP.csv
#   inflating: Raw Data Files/FieldOfStudyData1516_1617_PP.csv
#   inflating: Raw Data Files/Most-Recent-Cohorts-Field-of-Study.csv
#   inflating: Raw Data Files/MERGED2012_13_PP.csv
#   inflating: Raw Data Files/MERGED2005_06_PP.csv
#   inflating: Raw Data Files/MERGED2009_10_PP.csv
#   inflating: Raw Data Files/FieldOfStudyData1617_1718_PP.csv
#   inflating: Raw Data Files/MERGED2018_19_PP.csv
#   inflating: Raw Data Files/MERGED2017_18_PP.csv
# ...

# %%
# <1> 
# Import libraries

#(Write code here)
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import os

# %%
#will get an error if we don't specify the path as /content/Raw Data Files 
# %cd  "/content/Raw Data Files"
# Out:
# /content/Raw Data Files

# %%
# <2> 
# Display the current workin directory using os.getcwd()
# you would need to import a standard Python library called os which stands for operating system,
# so place that import statement in the previous cell.
# Since your notebook and your data files are not in # the same folder, 
# you want to make sure what is the current working folder and 
# how to access a data file in a different folder

#(Write code here)
os.getcwd()
# Out:
# '/content/Raw Data Files'

# %%
# <3> 
# os library has a method call listdir which generates a list of files in a directory/folder.
# use this method to assign the contents (list of file names) of the data folder to a variable and display it.
# # You can use ../ construct to traverse to the parent folder and then to another foloder parallel to the current folder

#(Write code here)
files = os.listdir('/content/Raw Data Files')
files
# Out:
# ['Crosswalks.zip',
#  'MERGED2014_15_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'Most-Recent-Cohorts-Field-of-Study.csv',
#  'MERGED2009_10_PP.csv',
#  'FieldOfStudyData1617_1718_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'data.yaml',
#  'MERGED1999_00_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'FieldOfStudyData1516_1617_PP.csv',
#  'FieldOfStudyData1415_1516_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2018_19_PP.csv',
#  'Most-Recent-Cohorts-All-Data-Elements.csv']

# %%
# <4> 
# The folder contains files that are not the yearly data files
# write code to remove the unwanted files from the list vsriable 
# Note: don't remove/delete these files from the folder in your drive
# For example, use the file extension to only keep the csv files 
# or use the name patter - data file name begins with "MERGED"
# You can use the concept of list comprehension to write just 
# one line of code as well as using a for loop, your choice.

#(Write code here)
yearly_files = [i for i in files if 'MERGED' in i ]
yearly_files
# Out:
# ['MERGED2014_15_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2018_19_PP.csv']

# %%
# <5> 
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load six columns: 
# ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"].
# You should use "usecols" option of Pandas to avoid reading unwanted columns.
# You also want to add a new column call "YEAR" to differentiate the data frames from each other.
# The YEAR variable should be yyyy format so tht you can convert them into integer.
# if you use the format yyyy-yy (such as 1997-98 school year), you will not be able to convert them directly to integer
# if you use scatter plot, the YEAR needs to be converted to integer or float. 
# 
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a 
# new single data frame.
# Note: this exercise incorporates many techques we learned before
# - list (creating an empty, append an item to the list)
# - for loop 
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
# This exercise may appear a big challenging but it worths the effort. You will learn a lot and  love it. I promise.

#(Write code here)
li = []

for filename in yearly_files:
    df = pd.read_csv(filename, usecols=["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
    li.append(df)

li
# Out:
# [        UNITID  ... TUITIONFEE_IN
#  0       100654  ...        9096.0
#  1       100663  ...        7510.0
#  2       100690  ...        6900.0
#  3       100706  ...        9158.0
#  4       100724  ...        8720.0
#  ...        ...  ...           ...
#  7761  48065701  ...       10764.0
#  7762  48154401  ...           NaN
#  7763  48387801  ...           NaN
#  7764  48400201  ...       29932.0
#  7765  48414501  ...           NaN
#
#  [7766 rows x 6 columns],         UNITID  ... TUITIONFEE_IN
#  0       100636  ...           NaN
#  1       100654  ...        4072.0
#  2       100663  ...        4664.0
#  3       100690  ...        6600.0
#  4       100706  ...        5952.0
#  ...        ...  ...           ...
#  7050  44098901  ...           NaN
#  7051  44098902  ...           NaN
#  7052  44098903  ...           NaN
#  7053  44098904  ...           NaN
#  7054  44098905  ...           NaN
#
# ...

# %%
# to append year to the data frame
for i in yearly_files:
  year = i[6:10]
year
# Out:
# '2018'

# %%
final_data = []
for filename in yearly_files:
    df1 = pd.read_csv(filename, usecols=["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
    years = filename[6:10]
    df1['year'] = years
    final_data.append(df1)

# %%
final_data
# Out:
# [        UNITID                                    INSTNM  ... TUITIONFEE_IN  year
#  0       100654                  Alabama A & M University  ...        9744.0  2018
#  1       100663       University of Alabama at Birmingham  ...        8568.0  2018
#  2       100690                        Amridge University  ...        6900.0  2018
#  3       100706       University of Alabama in Huntsville  ...       10714.0  2018
#  4       100724                  Alabama State University  ...       11068.0  2018
#  ...        ...                                       ...  ...           ...   ...
#  6801  48511112         Georgia Military College - Dublin  ...        6120.0  2018
#  6802  48511113        Georgia Military College - Eastman  ...        6120.0  2018
#  6803  48616901  American College of Barbering - Florence  ...           NaN  2018
#  6804  49005401      HCI College - Fort Lauderdale Campus  ...       21420.0  2018
# ...

# %%
new_df = pd.concat(final_data)

# %%
new_df
# Out:
#         UNITID                                    INSTNM  ... TUITIONFEE_IN  year
# 0       100654                  Alabama A & M University  ...        9096.0  2014
# 1       100663       University of Alabama at Birmingham  ...        7510.0  2014
# 2       100690                        Amridge University  ...        6900.0  2014
# 3       100706       University of Alabama in Huntsville  ...        9158.0  2014
# 4       100724                  Alabama State University  ...        8720.0  2014
# ...        ...                                       ...  ...           ...   ...
# 6801  48511112         Georgia Military College - Dublin  ...        6120.0  2018
# 6802  48511113        Georgia Military College - Eastman  ...        6120.0  2018
# 6803  48616901  American College of Barbering - Florence  ...           NaN  2018
# 6804  49005401      HCI College - Fort Lauderdale Campus  ...       21420.0  2018
# ...

# %%
# <6> 
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

#(Write code here)
new_df.head(10) #top  10 values
# Out:
#    UNITID                               INSTNM  ... TUITIONFEE_IN  year
# 0  100654             Alabama A & M University  ...        9096.0  2014
# 1  100663  University of Alabama at Birmingham  ...        7510.0  2014
# 2  100690                   Amridge University  ...        6900.0  2014
# 3  100706  University of Alabama in Huntsville  ...        9158.0  2014
# 4  100724             Alabama State University  ...        8720.0  2014
# 5  100751            The University of Alabama  ...        9826.0  2014
# 6  100760    Central Alabama Community College  ...        3491.0  2014
# 7  100812              Athens State University  ...           NaN  2014
# 8  100830      Auburn University at Montgomery  ...        9080.0  2014
# 9  100858                    Auburn University  ...       10200.0  2014
#
# [10 rows x 7 columns]

# %%
new_df.tail(10) #last 10 values
# Out:
#         UNITID                                     INSTNM  ... TUITIONFEE_IN  year
# 6796  48511107        Georgia Military College - Columbus  ...        6120.0  2018
# 6797  48511108    Georgia Military College - Sandersville  ...        6120.0  2018
# 6798  48511109         Georgia Military College - Madison  ...        6120.0  2018
# 6799  48511110  Georgia Military College - Stone Mountain  ...        6120.0  2018
# 6800  48511111    Georgia Military College - Fayetteville  ...        6120.0  2018
# 6801  48511112          Georgia Military College - Dublin  ...        6120.0  2018
# 6802  48511113         Georgia Military College - Eastman  ...        6120.0  2018
# 6803  48616901   American College of Barbering - Florence  ...           NaN  2018
# 6804  49005401       HCI College - Fort Lauderdale Campus  ...       21420.0  2018
# 6805  49146401           ABC Adult School - Cabrillo Lane  ...           NaN  2018
#
# [10 rows x 7 columns]

# %%
new_df.describe()
# Out:
#              UNITID         REGION      ADM_RATE  TUITIONFEE_IN
# count  1.633310e+05  163330.000000  44912.000000   79195.000000
# mean   9.432395e+05       4.554693      0.692951   11665.636871
# std    4.571721e+06       2.189217      0.217058    9986.003542
# min    1.006360e+05       0.000000      0.000000       0.000000
# 25%    1.633380e+05       3.000000      0.555075    3776.000000
# 50%    2.127800e+05       5.000000      0.717500    9285.000000
# 75%    4.075680e+05       6.000000      0.857100   16148.000000
# max    4.914640e+07       9.000000      1.000000   74787.000000

# %%
new_df.plot()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163331 entries, 0 to 6805
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   UNITID         163331 non-null  int64
#  1   INSTNM         163331 non-null  object
#  2   STABBR         163331 non-null  object
#  3   REGION         163330 non-null  float64
#  4   ADM_RATE       44912 non-null   float64
#  5   TUITIONFEE_IN  79195 non-null   float64
#  6   year           163331 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 10.0+ MB

# %%
# <7>
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at UMBC
# filter/query the dataframe to retrieve only rows that belong to UMBC
# save the UMNC data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

#(Write code here)
find_maryland = new_df[new_df['STABBR']=='MD']
find_maryland
# Out:
#         UNITID                                  INSTNM  ... TUITIONFEE_IN  year
# 1575    161615               Aaron's Academy of Beauty  ...           NaN  2014
# 1576    161651     Aesthetics Institute of Cosmetology  ...           NaN  2014
# 1577    161688            Allegany College of Maryland  ...        3540.0  2014
# 1578    161767          Anne Arundel Community College  ...        4350.0  2014
# 1579    161776               Brightwood College-Towson  ...           NaN  2014
# ...        ...                                     ...  ...           ...   ...
# 6461  16210401          Cecil College - Elkton Station  ...        4500.0  2018
# 6676  43018401     Strayer University-Rockville Campus  ...       13380.0  2018
# 6677  43018402  Strayer University-Anne Arundel Campus  ...       13380.0  2018
# 6678  43018403   Strayer University-White Marsh Campus  ...       13380.0  2018
# 6679  43018404  Strayer University-Owings Mills Campus  ...       13380.0  2018
#
# ...

# %%
Find_UMBC = new_df.loc[new_df['INSTNM'] == 'University of Maryland-Baltimore County']
Find_UMBC
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  year
# 1610  163268  University of Maryland-Baltimore County  ...       10384.0  2014
# 1767  163268  University of Maryland-Baltimore County  ...        8780.0  2008
# 1710  163268  University of Maryland-Baltimore County  ...        9171.0  2010
# 1915  163268  University of Maryland-Baltimore County  ...        5910.0  2001
# 1779  163268  University of Maryland-Baltimore County  ...        8708.0  2007
# 1510  163268  University of Maryland-Baltimore County  ...       11264.0  2016
# 2151  163268  University of Maryland-Baltimore County  ...           NaN  1996
# 1745  163268  University of Maryland-Baltimore County  ...        8872.0  2009
# 1830  163268  University of Maryland-Baltimore County  ...        8020.0  2004
# 1694  163268  University of Maryland-Baltimore County  ...        9467.0  2011
# 1555  163268  University of Maryland-Baltimore County  ...       11006.0  2015
# ...

# %%
# <8>
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

#(Write code here)
Find_UMBC.head()
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  year
# 1610  163268  University of Maryland-Baltimore County  ...       10384.0  2014
# 1767  163268  University of Maryland-Baltimore County  ...        8780.0  2008
# 1710  163268  University of Maryland-Baltimore County  ...        9171.0  2010
# 1915  163268  University of Maryland-Baltimore County  ...        5910.0  2001
# 1779  163268  University of Maryland-Baltimore County  ...        8708.0  2007
#
# [5 rows x 7 columns]

# %%
Find_UMBC.tail()
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  year
# 1629  163268  University of Maryland-Baltimore County  ...       10068.0  2013
# 1893  163268  University of Maryland-Baltimore County  ...        6362.0  2002
# 1478  163268  University of Maryland-Baltimore County  ...       11518.0  2017
# 2049  163268  University of Maryland-Baltimore County  ...           NaN  1997
# 1415  163268  University of Maryland-Baltimore County  ...       11778.0  2018
#
# [5 rows x 7 columns]

# %%
Find_UMBC.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN
# count      23.0    23.0  18.000000      19.000000
# mean   163268.0     2.0   0.640694    9004.842105
# std         0.0     0.0   0.052728    1825.795421
# min    163268.0     2.0   0.568300    5490.000000
# 25%    163268.0     2.0   0.597600    8270.000000
# 50%    163268.0     2.0   0.632100    8872.000000
# 75%    163268.0     2.0   0.689375   10226.000000
# max    163268.0     2.0   0.717400   11778.000000

# %%
Find_UMBC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1610 to 1415
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UNITID         23 non-null     int64
#  1   INSTNM         23 non-null     object
#  2   STABBR         23 non-null     object
#  3   REGION         23 non-null     float64
#  4   ADM_RATE       18 non-null     float64
#  5   TUITIONFEE_IN  19 non-null     float64
#  6   year           23 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.4+ KB

# %%
# <9> 
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Bar Chart

#(Write code here)
fig = go.Figure()

trace_0 = go.Bar(
    x = Find_UMBC['year'],
    y = Find_UMBC['TUITIONFEE_IN'],
    #mode = 'markers'
    #mode = 'markers+lines'
)

fig.add_trace(trace_0)

fig.update_layout(
    title = 'UMBC in-state tuition fee',
    xaxis = {'title':'year'},
    yaxis = {'title':'tuition fee'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b5ea4166-8a04-4b65-8b83-02be44a9c3dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5ea4166-8a04-4b65-8b83-02be44a9c3dc")) {
#                     Plotly.newPlot(
#                         'b5ea4166-8a04-4b65-8b83-02be44a9c3dc',
# ...

# %%
# <10> 
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Line Chart

#(Write code here)
fig = go.Figure()

new_umbc = Find_UMBC.sort_values(by='TUITIONFEE_IN', ascending=True)
trace_0 = go.Line(
    x = new_umbc['year'],
    y = new_umbc['TUITIONFEE_IN'],
    #mode = 'markers'
    mode = 'markers+lines'
)

fig.add_trace(trace_0)

fig.update_layout(
    title = 'UMBC in-state tuition fee',
    xaxis = {'title':'year'},
    yaxis = {'title':'tuition fee'}
)

fig.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d3e24602-5b42-42c9-abfe-60b2c5875f85" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
# <11>
# Now let's look at the tuition growth rate year over year
# We need to calculate UMBC tuition change percentage each year
# First convert the TUITIONFEE_IN column to a Python List

#(Write code here)
new_umbc['percentage_change'] = new_umbc['TUITIONFEE_IN'].pct_change()
new_umbc
# Out:
#       UNITID                                   INSTNM  ...  year  percentage_change
# 1926  163268  University of Maryland-Baltimore County  ...  2000                NaN
# 1915  163268  University of Maryland-Baltimore County  ...  2001           0.076503
# 1893  163268  University of Maryland-Baltimore County  ...  2002           0.076481
# 1873  163268  University of Maryland-Baltimore County  ...  2003           0.161270
# 1830  163268  University of Maryland-Baltimore County  ...  2004           0.085544
# 1819  163268  University of Maryland-Baltimore County  ...  2005           0.062344
# 1799  163268  University of Maryland-Baltimore County  ...  2006           0.011972
# 1779  163268  University of Maryland-Baltimore County  ...  2007           0.009974
# 1767  163268  University of Maryland-Baltimore County  ...  2008           0.008268
# 1745  163268  University of Maryland-Baltimore County  ...  2009           0.010478
# ...

# %%
# Loop through the list and calculate the % change each year over the prior year
# This takes some effort. Not hard, just some abstract/logical thinking and some experiments
# Have fun on this one

 #(Write code here)
 # i have used the function pct_change to calculate the percentage change in the bove cell

# %%
# The resulting number has many decimal points which are unnecessary and not visually appealing.
# Round up the percentage to two decimal points
# You can use for loop. Or better, use list comprehension for simplicity/brevity

#(Write code here)
new_umbc['percentage_change'] = new_umbc['percentage_change'].round(decimals = 2)
new_umbc
# Out:
#       UNITID                                   INSTNM  ...  year  percentage_change
# 1926  163268  University of Maryland-Baltimore County  ...  2000                NaN
# 1915  163268  University of Maryland-Baltimore County  ...  2001               0.08
# 1893  163268  University of Maryland-Baltimore County  ...  2002               0.08
# 1873  163268  University of Maryland-Baltimore County  ...  2003               0.16
# 1830  163268  University of Maryland-Baltimore County  ...  2004               0.09
# 1819  163268  University of Maryland-Baltimore County  ...  2005               0.06
# 1799  163268  University of Maryland-Baltimore County  ...  2006               0.01
# 1779  163268  University of Maryland-Baltimore County  ...  2007               0.01
# 1767  163268  University of Maryland-Baltimore County  ...  2008               0.01
# 1745  163268  University of Maryland-Baltimore County  ...  2009               0.01
# ...

# %%
# Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")
# Not as hard as you may think. If you get stuck, you think too hard. 
# Google it and you will find the answer.

#(Write code here)
new_umbc.columns = ['UNITID','INSTNM',	'STABBR',	'REGION',	'ADM_RATE',	'TUITIONFEE_IN',	'year',	'PCT_CHANGE']
new_umbc
# Out:
#       UNITID                                   INSTNM  ...  year  PCT_CHANGE
# 1926  163268  University of Maryland-Baltimore County  ...  2000         NaN
# 1915  163268  University of Maryland-Baltimore County  ...  2001        0.08
# 1893  163268  University of Maryland-Baltimore County  ...  2002        0.08
# 1873  163268  University of Maryland-Baltimore County  ...  2003        0.16
# 1830  163268  University of Maryland-Baltimore County  ...  2004        0.09
# 1819  163268  University of Maryland-Baltimore County  ...  2005        0.06
# 1799  163268  University of Maryland-Baltimore County  ...  2006        0.01
# 1779  163268  University of Maryland-Baltimore County  ...  2007        0.01
# 1767  163268  University of Maryland-Baltimore County  ...  2008        0.01
# 1745  163268  University of Maryland-Baltimore County  ...  2009        0.01
# 1710  163268  University of Maryland-Baltimore County  ...  2010        0.03
# ...

# %%
# Finaly, we can make the plot tuition growth rate year over year - bar first, then line chart

# (write code here)

fig = go.Figure()

trace_0 = go.Bar(
    x = new_umbc['year'],
    y = new_umbc['PCT_CHANGE'],
    #mode = 'markers'
    #mode = 'markers+lines'
)

fig.add_trace(trace_0)

fig.update_layout(
    title = 'UMBC in-state tuition fee',
    xaxis = {'title':'year'},
    yaxis = {'title':'pct_change tuition fee'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="24dd7d49-8372-4798-8dbf-c027f31967fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("24dd7d49-8372-4798-8dbf-c027f31967fd")) {
#                     Plotly.newPlot(
#                         '24dd7d49-8372-4798-8dbf-c027f31967fd',
# ...

# %%
# <12>
# Since we want to do the same calculation for JHU. 
# Instead of doing it piecemeal as we did for UMBC
# Let's create a function which can be reused for any college.
# This function takes a list of tuitions and return a list of percentage changes year over year
# This function can be used later 

#(Write code here)

def percent_change(tuition):
  """Calculates percentage change in list of tuition tuit"""
  per_change = []
  per_change1 = []
  per_tuition_change = []
  for i in tuition:
    per_change = (i - (i-1)) / (i-1) * 100
    per_change1 = round(per_change,3)
    per_tuition_change.append(per_change1)
  return per_tuition_change

# %%
# <13>
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at JHU
# filter/query the dataframe to retrieve only rows that belong to JHU
# save the JHU data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

#(Write code here)
find_jhs = new_df.loc[new_df['INSTNM'] == 'Johns Hopkins University']
find_jhs
# Out:
#       UNITID                    INSTNM STABBR  ...  ADM_RATE  TUITIONFEE_IN  year
# 1603  162928  Johns Hopkins University     MD  ...    0.1608        47060.0  2014
# 1760  162928  Johns Hopkins University     MD  ...    0.2609        37700.0  2008
# 1703  162928  Johns Hopkins University     MD  ...    0.2225        40680.0  2010
# 1906  162928  Johns Hopkins University     MD  ...    0.3431        26210.0  2001
# 1772  162928  Johns Hopkins University     MD  ...    0.2571        35900.0  2007
# 1503  162928  Johns Hopkins University     MD  ...    0.1284        50410.0  2016
# 2139  162928  Johns Hopkins University     MD  ...       NaN            NaN  1996
# 1738  162928  Johns Hopkins University     MD  ...    0.2782        39150.0  2009
# 1823  162928  Johns Hopkins University     MD  ...    0.3071        30140.0  2004
# 1687  162928  Johns Hopkins University     MD  ...    0.1940        42280.0  2011
# ...

# %%
# <14> 
# Plot JHU's in-state tuition overtime from 1996 to 2019. 
# Let's plot bar and line chart together

#(Write code here)
fig = go.Figure()

trace_0 = go.Bar(
    x = find_jhs['year'],
    y = find_jhs['TUITIONFEE_IN'],
    #mode = 'markers'
    #mode = 'markers+lines'
)

fig.add_trace(trace_0)

fig.update_layout(
    title = 'JHS in-state tuition fee',
    xaxis = {'title':'year'},
    yaxis = {'title':'tuition fee'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="41fe6820-c53b-4a81-b3c3-130bfbfa95c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41fe6820-c53b-4a81-b3c3-130bfbfa95c9")) {
#                     Plotly.newPlot(
#                         '41fe6820-c53b-4a81-b3c3-130bfbfa95c9',
# ...

# %%
fig = go.Figure()

new_jhs = find_jhs.sort_values(by='TUITIONFEE_IN', ascending=True)
trace_0 = go.Line(
    x = new_jhs['year'],
    y = new_jhs['TUITIONFEE_IN'],
    #mode = 'markers'
    mode = 'markers+lines'
)

fig.add_trace(trace_0)

fig.update_layout(
    title = 'JHS in-state tuition fee',
    xaxis = {'title':'year'},
    yaxis = {'title':'tuition fee'}
)

fig.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1cff9537-4ffa-4911-b632-c78fc3c36282" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
# <15>
# Let's calculate the JHU tuition percentge growth using the function defined earlier

#(Write code here)
jhs_percent = new_jhs['TUITIONFEE_IN']
jhs_pct_change = percent_change(jhs_percent)
jhs_pct_change
# Out:
# [0.004,
#  0.004,
#  0.004,
#  0.003,
#  0.003,
#  0.003,
#  0.003,
#  0.003,
#  0.003,
#  0.003,
#  0.002,
#  0.002,
#  0.002,
#  0.002,
#  0.002,
#  0.002,
#  0.002,
#  0.002,
#  0.002,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
# <16>
# Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

#(Write code here)

new_jhs['PCT_CHANGE'] = jhs_pct_change
new_jhs
# Out:
#       UNITID                    INSTNM STABBR  ...  TUITIONFEE_IN  year  PCT_CHANGE
# 1917  162928  Johns Hopkins University     MD  ...        24930.0  2000       0.004
# 1906  162928  Johns Hopkins University     MD  ...        26210.0  2001       0.004
# 1884  162928  Johns Hopkins University     MD  ...        27390.0  2002       0.004
# 1865  162928  Johns Hopkins University     MD  ...        28730.0  2003       0.003
# 1823  162928  Johns Hopkins University     MD  ...        30140.0  2004       0.003
# 1812  162928  Johns Hopkins University     MD  ...        31620.0  2005       0.003
# 1792  162928  Johns Hopkins University     MD  ...        33900.0  2006       0.003
# 1772  162928  Johns Hopkins University     MD  ...        35900.0  2007       0.003
# 1760  162928  Johns Hopkins University     MD  ...        37700.0  2008       0.003
# 1738  162928  Johns Hopkins University     MD  ...        39150.0  2009       0.003
# ...

# %%
# <17> Make a bar plot of the JHU percentage changes tuitions over time

#(Write code here)

fig = go.Figure()

trace_0 = go.Bar(
    x = new_jhs['year'],
    y = new_jhs['PCT_CHANGE'],
    #mode = 'markers'
    #mode = 'markers+lines'
)

fig.add_trace(trace_0)

fig.update_layout(
    title = 'JHS in-state tuition fee percentage change',
    xaxis = {'title':'year'},
    yaxis = {'title':'percentage change tuition fee'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5243b681-511c-4a70-9718-07655ed63ee4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5243b681-511c-4a70-9718-07655ed63ee4")) {
#                     Plotly.newPlot(
#                         '5243b681-511c-4a70-9718-07655ed63ee4',
# ...

# %%
# <18>
# In order to plot both UMBC and JHU tuition change over time in the same plot,
# we need to combine the two datasets using the common key of YEAR 
# First make a umbc2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "UMBC_PCT" in preparation for the merge.
# This is because both umbc and jhu dataframe have the same column name "PCT_CHANGE",
# We rename them to there is no collision during the merge. BTW, Pandas handles collision gracefully,
# Feel free to try it without changing the column names.

#(Write code here)

new_umbc1 = new_umbc.drop(['UNITID',	'INSTNM',	'STABBR',	'REGION',	'ADM_RATE','TUITIONFEE_IN'], axis = 1)
new_umbc1
# Out:
#       year  PCT_CHANGE
# 1926  2000         NaN
# 1915  2001        0.08
# 1893  2002        0.08
# 1873  2003        0.16
# 1830  2004        0.09
# 1819  2005        0.06
# 1799  2006        0.01
# 1779  2007        0.01
# 1767  2008        0.01
# 1745  2009        0.01
# 1710  2010        0.03
# 1694  2011        0.03
# 1660  2012        0.03
# 1629  2013        0.03
# 1610  2014        0.03
# 1555  2015        0.06
# 1510  2016        0.02
# 1478  2017        0.02
# 1415  2018        0.02
# 2151  1996        0.00
# 1955  1999        0.00
# 1982  1998        0.00
# 2049  1997        0.00

# %%
new_umbc1.columns = ['year','UMBC_PCT']
new_umbc1
# Out:
#       year  UMBC_PCT
# 1926  2000       NaN
# 1915  2001      0.08
# 1893  2002      0.08
# 1873  2003      0.16
# 1830  2004      0.09
# 1819  2005      0.06
# 1799  2006      0.01
# 1779  2007      0.01
# 1767  2008      0.01
# 1745  2009      0.01
# 1710  2010      0.03
# 1694  2011      0.03
# 1660  2012      0.03
# 1629  2013      0.03
# 1610  2014      0.03
# 1555  2015      0.06
# 1510  2016      0.02
# 1478  2017      0.02
# 1415  2018      0.02
# 2151  1996      0.00
# 1955  1999      0.00
# 1982  1998      0.00
# 2049  1997      0.00

# %%
new_umbc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1926 to 2049
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      23 non-null     object
#  1   UMBC_PCT  22 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 552.0+ bytes

# %%
new_umbc1.describe()
# Out:
#         UMBC_PCT
# count  22.000000
# mean    0.035455
# std     0.039125
# min     0.000000
# 25%     0.010000
# 50%     0.025000
# 75%     0.052500
# max     0.160000

# %%
# Then make a jhu2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "JHU_PCT"  in preparation for the merge

#(Write code here)

new_jhs1 = new_jhs.drop(['UNITID',	'INSTNM',	'STABBR',	'REGION',	'ADM_RATE','TUITIONFEE_IN'], axis = 1)
new_jhs1
# Out:
#       year  PCT_CHANGE
# 1917  2000       0.004
# 1906  2001       0.004
# 1884  2002       0.004
# 1865  2003       0.003
# 1823  2004       0.003
# 1812  2005       0.003
# 1792  2006       0.003
# 1772  2007       0.003
# 1760  2008       0.003
# 1738  2009       0.003
# 1703  2010       0.002
# 1687  2011       0.002
# 1653  2012       0.002
# 1622  2013       0.002
# 1603  2014       0.002
# 1548  2015       0.002
# 1503  2016       0.002
# 1473  2017       0.002
# 1410  2018       0.002
# 2139  1996         NaN
# 1946  1999         NaN
# 1973  1998         NaN
# 2039  1997         NaN

# %%
new_jhs1.columns = ['year','JHS_PCT']
new_jhs1
# Out:
#       year  JHS_PCT
# 1917  2000    0.004
# 1906  2001    0.004
# 1884  2002    0.004
# 1865  2003    0.003
# 1823  2004    0.003
# 1812  2005    0.003
# 1792  2006    0.003
# 1772  2007    0.003
# 1760  2008    0.003
# 1738  2009    0.003
# 1703  2010    0.002
# 1687  2011    0.002
# 1653  2012    0.002
# 1622  2013    0.002
# 1603  2014    0.002
# 1548  2015    0.002
# 1503  2016    0.002
# 1473  2017    0.002
# 1410  2018    0.002
# 2139  1996      NaN
# 1946  1999      NaN
# 1973  1998      NaN
# 2039  1997      NaN

# %%
new_jhs1['JHS_PCT'] = new_jhs1['JHS_PCT'].round(decimals = 4)

# %%
new_jhs1
# Out:
#       year  JHS_PCT
# 1917  2000    0.004
# 1906  2001    0.004
# 1884  2002    0.004
# 1865  2003    0.003
# 1823  2004    0.003
# 1812  2005    0.003
# 1792  2006    0.003
# 1772  2007    0.003
# 1760  2008    0.003
# 1738  2009    0.003
# 1703  2010    0.002
# 1687  2011    0.002
# 1653  2012    0.002
# 1622  2013    0.002
# 1603  2014    0.002
# 1548  2015    0.002
# 1503  2016    0.002
# 1473  2017    0.002
# 1410  2018    0.002
# 2139  1996      NaN
# 1946  1999      NaN
# 1973  1998      NaN
# 2039  1997      NaN

# %%
# Now, merger the two data frames
# and display the new dataframe

#(Write code here)

df_merged = pd.merge(new_umbc1, new_jhs1, left_on="year", right_on="year", how = "outer")
df_merged
# Out:
#     year  UMBC_PCT  JHS_PCT
# 0   2000       NaN    0.004
# 1   2001      0.08    0.004
# 2   2002      0.08    0.004
# 3   2003      0.16    0.003
# 4   2004      0.09    0.003
# 5   2005      0.06    0.003
# 6   2006      0.01    0.003
# 7   2007      0.01    0.003
# 8   2008      0.01    0.003
# 9   2009      0.01    0.003
# 10  2010      0.03    0.002
# 11  2011      0.03    0.002
# 12  2012      0.03    0.002
# 13  2013      0.03    0.002
# 14  2014      0.03    0.002
# 15  2015      0.06    0.002
# 16  2016      0.02    0.002
# 17  2017      0.02    0.002
# 18  2018      0.02    0.002
# 19  1996      0.00      NaN
# 20  1999      0.00      NaN
# 21  1998      0.00      NaN
# 22  1997      0.00      NaN

# %%
# Plot UMBC and JHU separately on the same plot 
# However, this does not work since the bars overlap.

#(Write code here)
df_merged.plot()

# %%
# Plot them together using y=["UMBC_PCT","JHU_PCT"] option of bar plot

#(Write code here)

df_merged.plot(kind = 'bar', x='year', y=['UMBC_PCT','JHS_PCT'], figsize=(20,9))

# %%
# Plot them together using y=["UMBC_PCT","JHU_PCT"] option of line plot
#(Write code here)

df_merged.plot(kind = 'line', x='year', y=['UMBC_PCT','JHS_PCT'], figsize=(20,9))

# %%
# <19> 
# document your observation/conclusion of the comparison plots (bar/line)
# use the following Markdown cell

# %% [markdown]
# ##### 1. in the year 2003 there was maximum change in percentage of tuition fee for umbc
#
# ##### 2. UMBC

# %% [markdown]
# #### Based on my observation of the plots
# #### 1.  in the year 2003 there was maximum change in percentage of tuition fee for umbc
# #### 2. The in-state tuition fee has gradually increased over the years
# #### 3. The change in percentage of tuition fee has decreased drastically between 2004 and 2005
# #### 4. between john hopkins and umbc we can observe that the in-tuition fee is more, irrespective of the year.
# #### ...
# #### blah, blah

# %%
# The end.
